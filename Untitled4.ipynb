# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median

# %%
df = pd.read_csv("C:/Users/changhyun/Desktop/vehicles.csv")
df.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# ...

# %%
columns=[ "price", "year", "condition", "paint_color", "posting_date","lat","long","type"]
df = df[columns]
df_year = df[(df["year"]>1999) & (df["year"]<2021)].copy()
df_year["year"] = df_year["year"].astype(int)

# %%
plt.figure(figsize=(15,4))
sns.countplot(data=df_year,x="paint_color")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(data= df_year,x="paint_color", y= "price", estimator=median, ci=None)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(data= df_year[df_year["paint_color"] == 'white'],x="year", y= "price", ci=None)
plt.show()

# %%
df_local = df_year[(df_year['lat']>24) & (df_year['lat']<50) & (df_year['long']>-125) & (df_year['long']<-65) & ((df_year["paint_color"] == 'white') | (df_year["paint_color"] == 'black') | (df_year["paint_color"] == 'silver'))]
plt.figure(figsize=(18,10))
plt.title('Region Compare')
sns.scatterplot(data=df_local, x="long",y="lat",hue='paint_color')
plt.show()
